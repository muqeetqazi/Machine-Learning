# %%
import pandas as pd

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('insurance_data.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age,df.bought_insurance,color='red',marker='*')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df[['age']],df.bought_insurance,test_size=0.3)

# %%
len(X_test)
# Out:
# 9

# %%
X_test
# Out:
#     age
# 4    46
# 16   25
# 8    62
# 25   54
# 15   55
# 19   18
# 18   19
# 12   27
# 2    47

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
X_train
# Out:
#     age
# 6    55
# 21   26
# 26   23
# 10   18
# 22   40
# 20   21
# 3    52
# 0    22
# 23   45
# 5    56
# 11   28
# 24   50
# 9    61
# 13   29
# 7    60
# 14   49
# 17   58
# 1    25

# %%
model.predict(X_test)
# Out:
# array([1, 0, 1, 1, 1, 0, 0, 0, 1], dtype=int64)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.41479846, 0.58520154],
#        [0.93945265, 0.06054735],
#        [0.06324365, 0.93675635],
#        [0.17949156, 0.82050844],
#        [0.15885796, 0.84114204],
#        [0.97747947, 0.02252053],
#        [0.97400712, 0.02599288],
#        [0.9204124 , 0.0795876 ],
#        [0.37963033, 0.62036967]])

# %%
model.score(X_test,y_test)
# Out:
# 0.8888888888888888
